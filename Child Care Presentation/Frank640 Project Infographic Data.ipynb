# %%
# Import modules
import pandas

# %%
# load data
childcareData = pandas.read_excel("nationaldatabaseofchildcareprices.xlsx")

# %%
childcareData['MCInfant'].mean()
# Out:
# np.float64(146.05176959267578)

# %%
data2008 = childcareData[childcareData['StudyYear'] == 2008]
data2018 = childcareData[childcareData['StudyYear'] == 2018]

# %%
print(data2008['MCInfant'].mean())
print(data2018['MCInfant'].mean())
# Out:
# 133.46815308988766
# 162.39207627118643

# %%
print(data2008['MCToddler'].mean())
print(data2018['MCToddler'].mean())
# Out:
# 118.56034410112359
# 145.95824152542372

# %%
print(data2008['MCPreschool'].mean())
print(data2018['MCPreschool'].mean())
# Out:
# 110.70807584269664
# 135.92098305084747

# %%
print(data2008['MCSA'].mean())
print(data2018['MCSA'].mean())
# Out:
# 89.69948735955057
# 112.58956355932203

# %%
print(data2008['MHI'].mean())
print(data2018['MHI'].mean())
# Out:
# 43464.59646721833
# 51577.71440483768

# %%
print(data2008['MFCCInfant'].mean())
print(data2018['MFCCInfant'].mean())
print(data2008['MFCCToddler'].mean())
print(data2018['MFCCToddler'].mean())
print(data2008['MFCCPreschool'].mean())
print(data2018['MFCCPreschool'].mean())
print(data2008['MFCCSA'].mean())
print(data2018['MFCCSA'].mean())
# Out:
# 104.2362015503876
# 125.6150936967632
# 97.93778717406624
# 118.51021720613288
# 96.00431994362228
# 115.35306218057922
# 84.35177589852009
# 102.18224872231687
